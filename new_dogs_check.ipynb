# %%
import pandas as pd
from control_chart_class import Control_chart

# %%
data_df =  pd.read_excel('dog_treats_data.xlsx')

# %%
data_df.shape
# Out:
# (24, 6)

# %%
c_chart =  Control_chart()

# %%
c_chart.plot_control_char(data=data_df,kind='R',rules=['Rule 3'])

# %%
c_chart.plot_control_char(data=data_df,kind='x_mean',rules=['Rule 1','Rule 3','Rule 5'])
